# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('house_price.csv')

# %%
df.head()
# Out:
#    Bathrooms                                    Address  Land area       CV  \
# 0        3.0  106 Lawrence Crescent Hill Park, Auckland      714.0   960000
# 1        3.0             8 Corsica Way Karaka, Auckland      564.0  1250000
# 2        4.0     243 Harbourside Drive Karaka, Auckland      626.0  1250000
# 3        1.0  2/30 Hardington Street Onehunga, Auckland       65.0   740000
# 4        1.0     59 Israel Avenue Clover Park, Auckland      601.0   630000
#
#     Latitude   Longitude      SA1  0-19 years  20-29 years  30-39 years  \
# 0 -37.012920  174.904069  7009770          48           27           24
# 1 -37.063672  174.922912  7009991          42           18           12
# 2 -37.063580  174.924044  7009991          42           18           12
# 3 -36.912996  174.787425  7007871          42            6           21
# 4 -36.979037  174.892612  7008902          93           27           33
#
# ...

# %%
df. describe(include='all')
# Out:
#         Bathrooms                                 Address   Land area  \
# count    5.000000                                       5    5.000000
# unique        NaN                                       5         NaN
# top           NaN  59 Israel Avenue Clover Park, Auckland         NaN
# freq          NaN                                       1         NaN
# mean     2.400000                                     NaN  514.000000
# std      1.341641                                     NaN  257.008755
# min      1.000000                                     NaN   65.000000
# 25%      1.000000                                     NaN  564.000000
# 50%      3.000000                                     NaN  601.000000
# 75%      3.000000                                     NaN  626.000000
# max      4.000000                                     NaN  714.000000
#
#                   CV   Latitude   Longitude           SA1  0-19 years  \
# ...

# %%
df.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-0e566b70f572> in <module>
# ----> 1 df.shape()
#
# TypeError: 'tuple' object is not callable

# %%
df['Land area']
# Out:
# 0    714.0
# 1    564.0
# 2    626.0
# 3     65.0
# 4    601.0
# Name: Land area, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 20 columns):
# Bathrooms          5 non-null float64
# Address            5 non-null object
# Land area          5 non-null float64
# CV                 5 non-null int64
# Latitude           5 non-null float64
# Longitude          5 non-null float64
# SA1                5 non-null int64
# 0-19 years         5 non-null int64
# 20-29 years        5 non-null int64
# 30-39 years        5 non-null int64
# 40-49 years        5 non-null int64
# 50-59 years        5 non-null int64
# 60+ years          5 non-null int64
# Suburbs            5 non-null object
# Population         5 non-null int64
# NZDep2018          5 non-null float64
# NZDep2018_Score    5 non-null float64
# URPopnSA1_2018     5 non-null int64
# SA22018_code       5 non-null int64
# SA22018_name       5 non-null object
# dtypes: float64(6), int64(11), object(3)
# memory usage: 880.0+ bytes

# %%
df.head()
# Out:
#    Bathrooms                                    Address  Land area       CV  \
# 0        3.0  106 Lawrence Crescent Hill Park, Auckland      714.0   960000
# 1        3.0             8 Corsica Way Karaka, Auckland      564.0  1250000
# 2        4.0     243 Harbourside Drive Karaka, Auckland      626.0  1250000
# 3        1.0  2/30 Hardington Street Onehunga, Auckland       65.0   740000
# 4        1.0     59 Israel Avenue Clover Park, Auckland      601.0   630000
#
#     Latitude   Longitude      SA1  0-19 years  20-29 years  30-39 years  \
# 0 -37.012920  174.904069  7009770          48           27           24
# 1 -37.063672  174.922912  7009991          42           18           12
# 2 -37.063580  174.924044  7009991          42           18           12
# 3 -36.912996  174.787425  7007871          42            6           21
# 4 -36.979037  174.892612  7008902          93           27           33
#
# ...

# %%
def get_population(x, y):
    """
    Takes an address as a STRING input, returns the latitude and longitude coordinates as STRING outputs.
    """
    
    url = 'https://koordinates.com/services/query/v1/vector'

    params = {
        'key' : 'b2333372ea7942ec8261821bb48a4aec',
        'layer': '104612',
        'format' : 'json',
        'x': 'Longitude',
        'y':'Latitude'
    }

    response = requests.get(url, params=params)
    
    if response.status_code != 200:
        return pd.Series({'Population': response.status_code})

    Population = response.json()[0]['Population']
   
    return pd.Series({'Population': Population})

# %%
import json
import sys
sys.path.append('/home/nbuser/library/')

import pandas as pd
import requests

# %%
get_population('174.9040694','-37.0129205')
# Out:
# Population    406
# dtype: int64

# %%
df['Population']= df.apply(lambda row: get_population(row['Longitude'], row['Latitude']),axis =1 )

# %%
df.to_csv('house_price.csv', index=False)

# %%
df1 = df.head()

# %%
df1.head()
# Out:
#    Bathrooms                                    Address  Land area       CV  \
# 0        3.0  106 Lawrence Crescent Hill Park, Auckland      714.0   960000
# 1        3.0             8 Corsica Way Karaka, Auckland      564.0  1250000
# 2        4.0     243 Harbourside Drive Karaka, Auckland      626.0  1250000
# 3        1.0  2/30 Hardington Street Onehunga, Auckland       65.0   740000
# 4        1.0     59 Israel Avenue Clover Park, Auckland      601.0   630000
#
#     Latitude   Longitude      SA1  0-19 years  20-29 years  30-39 years  \
# 0 -37.012920  174.904069  7009770          48           27           24
# 1 -37.063672  174.922912  7009991          42           18           12
# 2 -37.063580  174.924044  7009991          42           18           12
# 3 -36.912996  174.787425  7007871          42            6           21
# 4 -36.979037  174.892612  7008902          93           27           33
#
# ...

# %%
df2= pd.read_csv('dpi.csv')

# %%
df2.head()
# Out:
#    SA12018_code  NZDep2018  NZDep2018_Score  URPopnSA1_2018  SA22018_code  \
# 0       7000000       10.0           1245.0             141        100100
# 1       7000001       10.0           1245.0             114        100100
# 2       7000002        NaN              NaN               0        100300
# 3       7000003       10.0           1207.0             225        100100
# 4       7000004        9.0           1093.0             138        100100
#
#                 SA22018_name
# 0                 North Cape
# 1                 North Cape
# 2  Inlets Far North District
# 3                 North Cape
# 4                 North Cape

# %%
values = {'NZDep2018': 0.0, 'NZDep2018_Score':0.0}
df2.fillna(value=values)
# Out:
#        SA12018_code  NZDep2018  NZDep2018_Score  URPopnSA1_2018  SA22018_code  \
# 0           7000000       10.0           1245.0             141        100100
# 1           7000001       10.0           1245.0             114        100100
# 2           7000002        0.0              0.0               0        100300
# 3           7000003       10.0           1207.0             225        100100
# 4           7000004        9.0           1093.0             138        100100
# 5           7000005       10.0           1253.0             174        100100
# 6           7000006        9.0           1093.0             105        100100
# 7           7000007        9.0           1072.0             240        100100
# 8           7000008        8.0           1044.0             228        100100
# 9           7000009        8.0           1029.0             120        100100
# 10          7000010        0.0              0.0               0        100300
# ...

# %%
df2.rename(columns={'SA12018_code':'SA1'}, 
                 inplace=True)

# %%
df2.head()
# Out:
#        SA1  NZDep2018  NZDep2018_Score  URPopnSA1_2018  SA22018_code  \
# 0  7000000       10.0           1245.0             141        100100
# 1  7000001       10.0           1245.0             114        100100
# 2  7000002        NaN              NaN               0        100300
# 3  7000003       10.0           1207.0             225        100100
# 4  7000004        9.0           1093.0             138        100100
#
#                 SA22018_name
# 0                 North Cape
# 1                 North Cape
# 2  Inlets Far North District
# 3                 North Cape
# 4                 North Cape

# %%
df = df1.merge(df2, how='left', on='SA1')

# %%
df.head()
# Out:
#    Bathrooms                                    Address  Land area       CV  \
# 0        3.0  106 Lawrence Crescent Hill Park, Auckland      714.0   960000
# 1        3.0             8 Corsica Way Karaka, Auckland      564.0  1250000
# 2        4.0     243 Harbourside Drive Karaka, Auckland      626.0  1250000
# 3        1.0  2/30 Hardington Street Onehunga, Auckland       65.0   740000
# 4        1.0     59 Israel Avenue Clover Park, Auckland      601.0   630000
#
#     Latitude   Longitude      SA1  0-19 years  20-29 years  30-39 years  \
# 0 -37.012920  174.904069  7009770          48           27           24
# 1 -37.063672  174.922912  7009991          42           18           12
# 2 -37.063580  174.924044  7009991          42           18           12
# 3 -36.912996  174.787425  7007871          42            6           21
# 4 -36.979037  174.892612  7008902          93           27           33
#
# ...

# %%
df.to_csv('house_price.csv', index=False)

# %%
df.head()
# Out:
#    Bathrooms                                    Address  Land area       CV  \
# 0        3.0  106 Lawrence Crescent Hill Park, Auckland      714.0   960000
# 1        3.0             8 Corsica Way Karaka, Auckland      564.0  1250000
# 2        4.0     243 Harbourside Drive Karaka, Auckland      626.0  1250000
# 3        1.0  2/30 Hardington Street Onehunga, Auckland       65.0   740000
# 4        1.0     59 Israel Avenue Clover Park, Auckland      601.0   630000
#
#     Latitude   Longitude      SA1  0-19 years  20-29 years  30-39 years  \
# 0 -37.012920  174.904069  7009770          48           27           24
# 1 -37.063672  174.922912  7009991          42           18           12
# 2 -37.063580  174.924044  7009991          42           18           12
# 3 -36.912996  174.787425  7007871          42            6           21
# 4 -36.979037  174.892612  7008902          93           27           33
#
#          ...          NZDep2018_x  NZDep2018_Score_x  URPopnSA1_2018_x  \
# ...

# %%
import seaborn as sns

# %%
df.hist(figsize=(20,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fa09d5b0f98>,
# ...
#       dtype=object)

# %%
sns.pairplot(df, size=5.0)
# Out:
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/seaborn/axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)

# %%
ax, fig= plt.subplots(figsize=(20,15))
correlation_matrix=df.corr()
sns.heatmap(correlation_matrix,annot=True, cmap="OrRd")
plt.show()

# %%
sns.distplot(df['CV'])
# Out:
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.distplot(df['CV'])

# %%
from sklearn.model_selection import train_test_split
x = df.drop(['Address','SA22018_name_x','Suburbs', 'CV'], axis=1)
x.head()
# Out:
#    Bathrooms  Land area   Latitude   Longitude      SA1  0-19 years  \
# 0        3.0      714.0 -37.012920  174.904069  7009770          48
# 1        3.0      564.0 -37.063672  174.922912  7009991          42
# 2        4.0      626.0 -37.063580  174.924044  7009991          42
# 3        1.0       65.0 -36.912996  174.787425  7007871          42
# 4        1.0      601.0 -36.979037  174.892612  7008902          93
#
#    20-29 years  30-39 years  40-49 years  50-59 years        ...          \
# 0           27           24           21           24        ...
# 1           18           12           21           15        ...
# 2           18           12           21           15        ...
# 3            6           21           21           12        ...
# 4           27           33           30           21        ...
#
#    Population  NZDep2018_x  NZDep2018_Score_x  URPopnSA1_2018_x  \
# 0         406          6.0              997.0               174
# ...

# %%
y=df['CV']
y.head()
# Out:
# 0     960000
# 1    1250000
# 2    1250000
# 3     740000
# 4     630000
# Name: CV, dtype: int64

# %%
train_x, tezt_x, train_y, test_y = train_test_split(x,y,test_size=0.3, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
model=LinearRegression()

# %%
model.fit(train_x,train_y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-94-cc9444c861c3> in <module>
# ----> 1 model.fit(train_x,train_y)
#
# ~/anaconda3_501/lib/python3.6/site-packages/sklearn/linear_model/base.py in fit(self, X, y, sample_weight)
#     456         n_jobs_ = self.n_jobs
#     457         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 458                          y_numeric=True, multi_output=True)
#     459
#     460         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# ~/anaconda3_501/lib/python3.6/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     754                     ensure_min_features=ensure_min_features,
# ...

# %%
model.coef_

# %%
predicted=model.predict(tezt_x)

# %%
plt.plot(test_y,predicted)

# %%
model.score(tezt_x, test_y)
